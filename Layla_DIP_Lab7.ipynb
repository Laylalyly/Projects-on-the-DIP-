# %%
import cv2
import matplotlib.pyplot as plt
img= cv2.imread('image.jpg', 0)

orb= cv2.ORB_create(nfeatures=5000)

kp,des=orb.detectAndCompute(img, None)

img_kp = cv2.drawKeypoints(img, kp, None, color=(255,0,0), flags=0)
plt.imshow(img_kp, cmap='gray')
plt.show()
# Out:
# Running cells with 'Python 3.12.9' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/layla/AppData/Local/Programs/Python/Python312/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
img1 = cv2.imread('image.jpg', 0)
img2 = cv2.imread('image.jpg', 0) 


kp1, des1 = orb.detectAndCompute(img1, None)
kp2, des2 = orb.detectAndCompute(img2, None)

bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)

matches = bf.match(des1, des2)

matches = sorted(matches, key = lambda x:x.distance)

img_matches = cv2.drawMatches(img1, kp1, img2, kp2, matches[:50], None, flags=2)

plt.imshow(img_matches, cmap='gray')
plt.show()

# %%
img = cv2.imread('color.jpeg', 0)


hog = cv2.HOGDescriptor()


hog_features = hog.compute(img)

print(f"HOG Feature Vector Shape: {hog_features.shape}")

# %%
# ============================================================
# 1. Load Image
# ============================================================

image = cv2.imread("street.jpg")

if image is None:
    raise FileNotFoundError(
        "Image not found. Make sure 'street.jpg' exists."
    )

# Keep a copy for visualization
output = image.copy()

# ============================================================
# 2. Initialize HOG + Pre-trained SVM
# ============================================================

hog = cv2.HOGDescriptor()

# Load OpenCV's pre-trained SVM detector for pedestrians
hog.setSVMDetector(
    cv2.HOGDescriptor_getDefaultPeopleDetector()
)

# ============================================================
# 3. Detect Pedestrians
# ============================================================

(boxes, weights) = hog.detectMultiScale(
    image,
    winStride=(4, 4),
    padding=(4, 4),
    scale=1.05
)

# ============================================================
# 4. Draw Bounding Boxes
# ============================================================
c_t = 0.6
f_d = []
for i, ((x, y, w, h), weight) in enumerate(
    zip(boxes, weights)
):
    c = float(weight)
    if c > c_t:
        f_d.append(
            ((x, y, w, h), c)
        )

        cv2.rectangle(
            output,
            (x, y),
            (x + w, y + h),
            (0, 255, 0),
            4
        )

        label = f"Person {i + 1}"

        cv2.putText(
            output,
            label,
            (x, y - 10),
            cv2.FONT_HERSHEY_SIMPLEX,
            2,
            (0, 255, 0),
            4
        )

# ============================================================
# 5. Print Results
# ============================================================

print(f"Number of pedestrians detected: {len(f_d)}")

for i, ((x, y, w, h), confidence) in enumerate(
    f_d
):
    print(
        f"Person {i + 1}: "
        f"x={x}, y={y}, width={w}, height={h}, "
        f"weight={float(confidence):.4f}"
    )

# ============================================================
# 6. Display Result
# ============================================================

output_rgb = cv2.cvtColor(
    output,
    cv2.COLOR_BGR2RGB
)

plt.figure(figsize=(14, 8))
plt.imshow(output_rgb)
plt.title(
    f"Pedestrian Detection "
    f"({len(f_d)} detected)"
)
plt.axis("off")
plt.show()

# %%
# Out:
# Running cells with 'Python 3.12.9' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/layla/AppData/Local/Programs/Python/Python312/python.exe -m pip install ipykernel -U --user --force-reinstall'
