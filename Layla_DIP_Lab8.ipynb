# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('color.jpg', 0)
template = cv2.imread('color.jpg', 0)
w, h = template.shape[::-1]
o = img.copy()


res = cv2.matchTemplate(img, template, cv2.TM_CCOEFF_NORMED)
threshold = 0.8
loc = np.where(res >= threshold)

for pt in zip(*loc[::-1]):
    cv2.rectangle(img, pt, (pt[0] + w, pt[1] + h), (255, 255, 255), 2)
    
output_rgb = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)
print(output_rgb.shape)
    
cv2.imshow('Faces Detected', output_rgb)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (710, 720, 3)

# %%
plt.figure(figsize=(12, 6))


plt.subplot(1, 3, 1)
plt.imshow(o, cmap="gray")
plt.title("Original")
plt.axis("off")


plt.subplot(1, 3, 2)
plt.imshow(template, cmap="gray")
plt.title("Template")
plt.axis("off")

plt.subplot(1, 3, 3)
plt.imshow(img, cmap="gray")
plt.title("Result")
plt.axis("off")

plt.show()

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-98190b696cb1> in <module>
# ----> 1 face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
#
# AttributeError: module 'cv2' has no attribute 'CascadeClassifier'

# %%
img = cv2.imread('color.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Detect faces
faces = face_cascade.detectMultiScale(gray, scaleFactor=1.2, minNeighbors=5, minSize=(30, 30))

# Draw bounding boxes
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)

cv2.imshow('Faces Detected', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-d3e7583dec59> in <module>
#       3
#       4 # Detect faces
# ----> 5 faces = face_cascade.detectMultiScale(gray, scaleFactor=1.2, minNeighbors=5, minSize=(30, 30))
#       6
#       7 # Draw bounding boxes
#
# NameError: name 'face_cascade' is not defined

# %%
cap = cv2.VideoCapture(0)

while True:
 # Read frame-by-frame
 ret, frame = cap.read()
 if not ret:
  break

 gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
 faces = face_cascade.detectMultiScale(gray, 1.1, 5)

 for (x, y, w, h) in faces:
  cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)

 # Display the resulting frame
 cv2.imshow('Real-time Face Detection', frame)

 # Press 'q' to exit the loop
 if cv2.waitKey(1) & 0xFF == ord('q'):
  break

# Release the capture safely
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-f1964bed861c> in <module>
#       9
#      10  gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
# ---> 11  faces = face_cascade.detectMultiScale(gray, 1.1, 5)
#      12
#      13  for (x, y, w, h) in faces:
#
# NameError: name 'face_cascade' is not defined
